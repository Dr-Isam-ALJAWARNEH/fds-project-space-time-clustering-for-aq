# %% [markdown]
# ### Policy-Aware Interpretation
#
# The used space-time clustering methods (KMeans, DBSCAN, and ST-DBSCAN) reveal relationships between urban mobility and air quality. The clustering outputs offered valuable insight into **how people move**, **where pollution concentrates**, and **when risks are highest**.
#
# - **ST-DBSCAN** uncovered hundreds of fine-grained clusters that aligned with **rush-hour congestion** and **pollution spikes**, showing how urban hotspots vary by time.
# - **KMeans** identified stable zones of activity and pollution overlap, useful for **fixed transit planning**.
# - **DBSCAN** revealed irregular clusters, showing where pollution doesn’t follow clean geographic boundaries — such as around large intersections or transportation hubs.
#
# Together, these methods offer a **layered understanding of urban risk**, combining space, time, and pollution intensity.

# %% [markdown]
# ## Policy Implications

# %% [markdown]
# Urban planners and policymakers can translate these clustering results into targeted, data-driven interventions:
#
# ####  1. **Public Transit Optimization**
# - Use **KMeans clusters** to identify neighborhoods with consistently high mobility demand and air pollution, ideal for:
#   - Adding new **bus or metro routes**
#   - Upgrading **public transport coverage** in underserved zones
#   - Designing **last-mile solutions** for hotspot zones
#
# ####  2. **Traffic Flow & Congestion Management**
# - Apply **ST-DBSCAN results** to adjust traffic control dynamically:
#   - **Reroute traffic** from space-time pollution clusters during peak hours
#   - Use results for **adaptive signal timing** and congestion alerts
#   - Create **time-based vehicle access zones**
#
# ####  3. **Pollution Mitigation Strategies**
# - Deploy **air quality sensors** and **real-time alerts** in the worst overlapping zones.
# - Implement **green infrastructure** (e.g., tree canopies, emission buffers) where clusters show recurring exposure.
# - Launch **public campaigns** targeting times/places where exposure is highest (e.g., school zones during morning commutes).
#
# ####  4. **Temporal Urban Policy**
# - ST-DBSCAN reveals **when** pollution is worst, not just where:
#   - Enforce **rush-hour tolls or carpool mandates**
#   - Promote **off-peak delivery schedules**
#   - Suggest **staggered work start times** to reduce load on specific regions
#
#
# **Conclusion**
#
# By combining space, time, and mobility data, urban stakeholders gain a high-resolution lens into **pollution dynamics**. These insights enable smarter planning that reduces environmental risk while improving mobility and quality of life.

# %% [markdown]
# ## Final Insight
#
# **Each clustering algorithm provided a different lens on the relationship between mobility and pollution:**
#
# *   KMeans supports infrastructure planning.
#
# *   DBSCAN aids in shape-flexible congestion detection.
# *   ST-DBSCAN delivers the richest spatio-temporal insights, essential for real-time, adaptive policy design.
#
#
# Together, these methods empower cities to balance urban mobility with environmental sustainability, aligning with smart city goals.
